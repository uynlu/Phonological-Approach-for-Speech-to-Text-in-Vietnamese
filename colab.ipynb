# %% [markdown]
# # Import modules

# %%
import torch
from torch.utils.data import ConcatDataset, DataLoader
import torch.optim as optim

# %%
# !pip install speechbrain
# Out:
# Collecting speechbrain
#   Downloading speechbrain-1.0.2-py3-none-any.whl.metadata (23 kB)
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from speechbrain) (24.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.5.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (2.32.3)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.18.8-py3-none-any.whl.metadata (22 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->speechbrain) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2024.12.14)
# Downloading speechbrain-1.0.2-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 14.4 MB/s eta 0:00:00
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.8-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 8.9 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 35.3 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, hyperpyyaml, speechbrain
# Successfully installed hyperpyyaml-1.2.2 ruamel.yaml-0.18.8 ruamel.yaml.clib-0.2.12 speechbrain-1.0.2

# %% [markdown]
# # Dataset

# %%
# convert_mp3_to_wav("Vietnamese-Speech-to-Text-datasets//Common-Voice")
# convert_mp3_to_wav("Vietnamese-Speech-to-Text-datasets//ViVOS")

# %% [markdown]
# ## Load dataset

# %%
import json
import torch
import itertools
import re
import string

# from dataset.text.word_decomposition import is_Vietnamese, decompose_non_vietnamese_word, compose_word


class Vocabulary:
    def __init__(self, paths):
        self.make_vocab(paths)
        self.make_idx()

    def __len__(self):
        return len(self.vocab) + 5

    def __getitem__(self, word):
        return self.word2idx.get(word, self.unk_idx)

    def __contains__(self, word):
        return word in self.word2idx

    def make_vocab(self, paths):
        self.vocab = set()
        self.max_len = 0
        for path in paths:
            with open(path, mode="r", encoding="utf-8") as file:
                data = json.load(file)
            data = list(data.items())
            for index in range(len(data)):
                sentence = data[index][1]['script']
                tokens = sentence.strip().split()
                if len(tokens) > self.max_len:
                    self.max_len = len(tokens)
                self.vocab.update(tokens)
        self.vocab = list(self.vocab)

    def make_idx(self):
        self.word2idx = {w: i for i, w in enumerate(self.vocab, 5)}
        self.pad_idx = 0
        self.bos_idx = 1
        self.eos_idx = 2
        self.blank_idx = 3
        self.unk_idx = 4
        self.idx2word = {i: w for w, i in self.word2idx.items()}

    def encode_script(self, script):
        encoded_script = []
        script = script.lower()
        pattern = f"[{re.escape(string.punctuation)}]"
        script = re.sub(pattern, "", script)
        words = script.split()
        for word in words:
            encoded_word = self.word2idx.get(word, self.unk_idx)
            encoded_script.append(encoded_word)
        return torch.tensor(encoded_script).long()


# class PhonemeVocabv2:
#     def __init__(self):
#         self.pad_idx = 0
#         self.bos_idx = 1
#         self.eos_idx = 2
#         self.blank_idx = 3

#         onsets = [
#             'ngh', 'tr', 'th', 'ph', 'nh', 'ng', 'kh',
#             'gi', 'gh', 'ch', 'q', 'đ', 'x', 'v', 't',
#             's', 'r', 'n', 'm', 'l', 'k', 'h', 'g', 'd',
#             'c', 'b'
#         ]
#         rhymes = [
#             # a
#             "a", "ac", "ach", "ai",
#             "am", "an", "ang", "anh",
#             "ao", "ap", "at", "ay", "au",
#             # ă
#             "ă", "ăc", "ăm", "ăn", "ăng", "ăp", "ăt",
#             # â
#             "â", "âc", "âm", "ân", "âng",
#             "âp", "ât", "âu", "ây",
#             # e
#             "e", "ec", "em", "en",
#             "eng", "eo", "ep", "et",
#             # ê
#             "ê", "êch", "êm", "ên",
#             "ênh", "êp", "êt", "êu",
#             # i
#             "i", "ia", "ich", "iêc", "iêm", "iên",
#             "iêng", "iêp", "iêt", "iêu", "im", "in",
#             "inh", "ip", "it", "iu",
#             # o
#             "o", "oa", "oac", "oach", "oai",
#             "oam", "oan", "oang", "oanh",
#             "oao", "oap", "oat", "oay",
#             "oăc", "oăm", "oăn", "oăng",
#             "oăt", "oc", "oe", "oen","oeo",
#             "oet", "oi", "om", "on", "ong",
#             "ooc", "oong", "op", "ot",
#             # ô
#             "ô", "ôc", "ôi",
#             "ôm", "ôn", "ông",
#             "ôp", "ôt",
#             # ơ
#             "ơ", "ơi", "ơm",
#             "ơn", "ơp", "ơt",
#             # u
#             "u", "ua", "uân", "uâng", "uât",
#             "uây", "uc", "uê", "uêch", "uênh",
#             "ui", "um", "un", "ung", "uơ", "uôc",
#             "uôi", "uôm", "uôn", "uông", "uôt",
#             "up", "ut", "uy", "uya", "uych",
#             "uyên", "uyêt", "uyn", "uynh",
#             "uyp", "uyt", "uyu",

#             "uach", "uai", "uan", "uang", "uanh", "uao", "uat", "uau", "uay",
#             "uăc", "uăm", "uăn", "uăng", "uăp", "uăt", "uâc", "uât",
#             "ue", "uen", "ueo", "uet", "uên", "uêt", "uêu",

#             # ư
#             "ư", "ưa", "ưc", "ưi",
#             "ưng", "ươc", "ươi",
#             "ươm", "ươn", "ương",
#             "ươp", "ươt", "ươu",
#             "ưt", "ưu",
#             # y
#             "y", "yêm", "yên",
#             "yêng", "yêt", "yêu"
#         ]
#         codas = ['ng', 'nh', 'ch', 'u', 'n', 'o', 'p', 'c', 'm', 'y', 'i', 't']
#         tones = ['<huyền>', '<sắc>', '<ngã>', '<hỏi>', '<nặng>']
#         phonemes = onsets + rhymes + codas + tones
#         self.phoneme2idx = {
#             phoneme: idx for idx, phoneme in enumerate(phonemes, start=4)
#         }
#         self.idx2phoneme = {idx: phoneme for phoneme, idx in self.phoneme2idx.items()}

#     def __len__(self):
#         return len(self.phoneme2idx) + 4

#     def encode_script(self, script: str):
#         script = script.lower()
#         pattern = f"[{re.escape(string.punctuation)}]"
#         script = re.sub(pattern, "", script)
#         words = script.split()
#         word_components = []
#         is_Vietnamese_words = []

#         for word in words:
#             if word == "quí":
#                 word = "quý"
#             is_Vietnamese_word, components = is_Vietnamese(word)
#             is_Vietnamese_words.append(is_Vietnamese_word)
#             if is_Vietnamese_word:
#                 word_components.append(components)
#             else:
#                 word_components.append(decompose_non_vietnamese_word(word))

#         phoneme_script = []
#         for ith in range(len(words)):
#             word_component = word_components[ith]
#             if is_Vietnamese_words[ith]:
#                 onset, medial, nucleus, coda, tone = word_component
#                 vowel = compose_word(None, medial, nucleus, coda, None)
#                 phoneme_script.extend([
#                     self.phoneme2idx[onset] if onset else self.blank_idx,
#                     self.phoneme2idx[vowel] if vowel else self.blank_idx,
#                     self.phoneme2idx[tone] if tone else self.blank_idx,
#                     self.blank_idx])
#             else:
#                 for char in word_component:
#                     onset, medial, nucleus, coda, tone = char
#                     vowel = compose_word(None, medial, nucleus, coda, None)
#                     phoneme_script.extend([
#                         self.phoneme2idx[onset] if onset else self.blank_idx,
#                         self.phoneme2idx[vowel] if vowel else self.blank_idx,
#                         self.phoneme2idx[tone] if tone else self.blank_idx,
#                         self.blank_idx])

#         vec = torch.tensor(phoneme_script[:-1]).long()  # remove the last blank token
#         return vec

#     def decode_script(self, tensor_script: torch.Tensor):
#         '''
#             tensorscript: (1, seq_len)
#         '''
#         # remove duplicated token
#         tensor_script = tensor_script.squeeze(0).long().tolist()
#         script = [self.idx2phoneme[idx] for idx in tensor_script]
#         script = ' '.join([k for k, _ in itertools.groupby(script)])

# %%
import torch.nn as nn
import torchaudio
from torchaudio import transforms
from torch.utils.data import Dataset
import json
import os
import torch.nn.functional as F


class MelSpectrogram(nn.Module):
    def __init__(self, sample_rate=16000, n_mels=64, win_length=400, hop_length=512, n_ffts=1024):
        # sample_rate: tần suất lấy mẫu (16000 điểm/s)
        # n_mels: chiều cao của Mel Spectrogram?
        # win_length: (nếu chiều dài của data là 800 => 2 window)
        # hop_length: bước nhảy (stride)
        # n_ffts: chiều dài mỗi Time-Section

        super(MelSpectrogram, self).__init__()

        self.transform = transforms.MelSpectrogram(
            sample_rate=sample_rate,
            n_mels=n_mels, win_length=win_length,
            hop_length=hop_length,
            n_fft=n_ffts
        )

    def forward(self, input):
        return self.transform(input)


class MFCC(nn.Module):
    def __init__(self, sample_rate=16000, n_mfcc=50, n_mels=64, win_length=400, hop_length=512, n_ffts=1024):
        super(MFCC, self).__init__()

        self.transform = transforms.MFCC(
            sample_rate=sample_rate,
            n_mfcc=n_mfcc,
            melkwargs={
                "n_mels": n_mels,
                "n_fft": n_ffts,
                "hop_length": hop_length
            }
        )

    def forward(self, input):
        return self.transform(input)


class CustomSpeech(Dataset):
    def __init__(self, audio_directory, data_directory, target_sample_rate, num_samples, transformation):
        super(CustomSpeech, self).__init__()

        self.audio_directory = audio_directory

        with open(data_directory, mode="r", encoding="utf-8") as file:
            data = json.load(file)
        self.data = list(data.items())

        if transformation == "Mel Spectrogram":
            self.transformation = MelSpectrogram()
        elif transformation == "MFCC":
            self.transformation = MFCC()

        self.target_sample_rate = target_sample_rate
        self.num_samples = num_samples

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        audio_path = self._get_audio_path(index)
        audio_wave, sample_rate = torchaudio.load(audio_path)  # (num_channels, origin_num_samples), int
        resampled_signal = self._resample_if_necessary(audio_wave, sample_rate)  # (num_channels, resampled_num_samples)
        cut_signal = self._cut_down_if_necessary(resampled_signal)  # (num_channels, num_samples)
        padded_signal = self._pad_if_necessary(cut_signal)  # (num_channels, num_samples)
        mel = self.transformation(padded_signal)  # (num_channels, num_mels, num_samples)
        mel = mel.squeeze()  # (num_mels, num_samples)
        mel = mel.permute(1, 0)  # (num_samples, num_mels)

        len_signal = cut_signal.size()[1]

        return mel, len_signal

    def _get_audio_path(self, index):
        file = (self.data[index][1]['voice']).replace(".mp3", ".wav")
        return os.path.join(self.audio_directory, file)

    def _resample_if_necessary(self, audio_wave, sample_rate):
        if sample_rate != self.target_sample_rate:
            resampler = transforms.Resample(sample_rate, self.target_sample_rate)
            audio_wave = resampler(audio_wave)
        return audio_wave

    def _cut_down_if_necessary(self, resampled_signal):
        cut_signal = resampled_signal.clone()
        if resampled_signal.size()[1] > self.num_samples:
            cut_signal = cut_signal[:, :self.num_samples]
        return cut_signal

    def _pad_if_necessary(self, cut_signal):
        padded_signal = cut_signal.clone()
        if padded_signal.size()[1] < self.num_samples:
            signal_length = padded_signal.size()[1]
            num_missing_samples = self.num_samples - signal_length
            last_dim_padding = (0, num_missing_samples)
            padded_signal = F.pad(padded_signal, last_dim_padding)
        return padded_signal


from torch.utils.data import Dataset
import json
# from dataset.text.vocabulary import PhonemeVocabv2
# import re
# import string
import torch
# import numpy as np

class CustomText(Dataset):
    def __init__(self, data_directory, vocab, max_len):
        super(CustomText, self).__init__()

        with open(data_directory, mode="r", encoding="utf-8") as file:
            data = json.load(file)
        self.data = list(data.items())

        self.vocab = vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        script = self.get_script(index)
        script = self.encode(script)
        script = self.cut_down_if_necessary(script)
        len_script = len(script)
        script = self.add_token(script)
        script = self.pad_if_necessary(script)
        return script, len_script

    def get_script(self, index):
        return self.data[index][1]["script"]

    # def _lower(self, script):
    #     lowered_script = script.lower()
    #     return lowered_script

    # def _remove_special_characters(self, lowered_script):
    #     pattern = f"[{re.escape(string.punctuation)}]"
    #     removed_script = re.sub(pattern, "", lowered_script)
    #     return removed_script

    # def _tokenize(self, removed_script):
    #     tokenized_script = self.vocab.tokenize(removed_script.split()[0])
    #     for word in removed_script.split()[1:]:
    #         tokenized_word = self.vocab.tokenize(word)
    #         tokenized_script = np.vstack((tokenized_script, tokenized_word))
    #     return tokenized_script

    def encode(self, script):
        return self.vocab.encode_script(script)

    def cut_down_if_necessary(self, script):
        if len(script) > self.max_len - 2:
            script = script[:self.max_len - 2]
        return script

    def add_token(self, script):
        return torch.cat((torch.tensor([self.vocab.bos_idx]), script, torch.tensor([self.vocab.eos_idx])))

    def pad_if_necessary(self, script):
        pad_value = torch.tensor([self.vocab.pad_idx])
        while len(script) < self.max_len:
            script = torch.cat((script, pad_value))
        return script

from torch.utils.data import Dataset
# from dataset.speech.speech import CustomSpeech
# from dataset.text.text import CustomText


class CustomDataset(Dataset):
    def __init__(self, audio_directory, data_directory, vocab, target_sample_rate, num_samples, transformation, max_len):
        super(CustomDataset, self).__init__()

        self.speech = CustomSpeech(audio_directory, data_directory, target_sample_rate, num_samples, transformation)
        self.script = CustomText(data_directory, vocab, max_len)

    def __len__(self):
        return len(self.speech)

    def __getitem__(self, index):
        return self.speech[index], self.script[index]

# %%
os.mkdir('ViVOS')
# !gdown 1oV2v0RBHX_Rqvra0YUrgoBgND0QC64Pc -O ViVOS/train.json
# !gdown 1obDaRybTfcOaGrl6mhAb5bMpMESs2lr5 -O ViVOS/test.json
# !gdown 1JoUgZ6uGPb5_iZTDinjF5pRzUvhk-4-n -O ViVOS/voices.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oV2v0RBHX_Rqvra0YUrgoBgND0QC64Pc
# To: /content/ViVOS/train.json
# 100% 2.28M/2.28M [00:00<00:00, 140MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1obDaRybTfcOaGrl6mhAb5bMpMESs2lr5
# To: /content/ViVOS/test.json
# 100% 135k/135k [00:00<00:00, 63.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1JoUgZ6uGPb5_iZTDinjF5pRzUvhk-4-n
# From (redirected): https://drive.google.com/uc?id=1JoUgZ6uGPb5_iZTDinjF5pRzUvhk-4-n&confirm=t&uuid=d1f6a2ca-48db-4817-8627-ab1b4d345d1c
# To: /content/ViVOS/voices.zip
# 100% 1.48G/1.48G [00:23<00:00, 62.1MB/s]

# %%
# !unzip "/content/ViVOS/voices.zip" -d "/content/ViVOS/voices"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_299.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_257.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_149.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R153.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R147.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R035.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_073.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_050.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_243.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R153.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R021.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_274.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV07_194.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_044.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_067.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_T023.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_255.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_237.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R009.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_117.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_078.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_175.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R009.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_103.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_161.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_248.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_078.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_241.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_T037.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_223.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_128.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_031.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_222.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_T036.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_240.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_249.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_025.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_236.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_128.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_254.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_T022.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV17_181.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_242.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_072.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R146.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_066.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_186.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_275.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV07_195.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R152.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_268.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R146.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV19_061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_072.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV18_272.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_192.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV05_251.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_261.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R098.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R152.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_256.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_298.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_066.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_002.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_211.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_273.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_226.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_035.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_099.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R073.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_179.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_283.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_297.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV04_T015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_232.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_021.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R067.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_016.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_205.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_267.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_099.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R185.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R191.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_213.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_009.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_145.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV05_286.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV07_156.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_151.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R185.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV04_T029.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_207.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_239.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R191.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_068.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_042.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_233.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R123.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_300.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_113.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_171.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R137.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_107.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_165.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_068.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_056.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_227.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R007.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_054.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_077.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV18_064.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_184.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R013.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_T047.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_253.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_063.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_040.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R007.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_289.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_247.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_159.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_054.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_077.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV15_047.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R013.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_T047.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_063.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_040.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_081.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_088.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_237.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_039.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_T014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_262.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV04_R114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_013.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_200.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV09_288.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_276.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV04_R100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_088.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_007.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_214.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_T014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_223.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_039.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_095.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_097.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R164.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_011.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_202.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_T028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV16_153.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_290.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV14_283.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_083.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R170.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_216.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_202.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_011.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_284.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_097.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R164.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_228.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_083.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R170.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_T028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_284.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_136.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_216.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_108.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_067.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_274.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R057.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_202.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_011.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_073.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_260.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_290.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_122.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_108.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV10_076.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_103.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_120.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R173.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_262.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_T041.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_134.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_117.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_039.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R167.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_248.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_198.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_103.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_120.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R173.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_276.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_134.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_117.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R167.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_262.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_T041.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_247.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_159.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_T012.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R198.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_167.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R094.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV17_208.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_173.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R080.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_T006.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_289.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R198.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_253.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_233.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_165.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_098.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV16_033.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_171.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_227.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_076.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_265.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_207.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_145.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_182.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_196.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_151.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_062.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_271.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_213.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_189.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_259.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_106.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R032.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_273.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_112.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R026.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_179.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R032.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_106.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R026.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_267.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_112.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_176.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R107.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_141.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_186.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_192.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R113.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_155.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_298.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_162.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV02_R005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_128.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_025.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_089.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_031.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_222.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_025.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV07_036.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_236.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_169.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV12_173.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_222.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_031.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_166.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_104.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_009.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_151.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R117.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_055.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_196.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_041.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_182.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV03_R029.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_145.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_009.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R103.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_288.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_172.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_110.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_170.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV02_R015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_099.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_138.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_035.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_069.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_164.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_021.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_232.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_179.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_035.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_226.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_170.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV17_032.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_021.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_164.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV09_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_217.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_109.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_066.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_275.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_096.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_058.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_155.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_192.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_186.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_082.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_141.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_203.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_072.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_261.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_058.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_135.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_249.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_199.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_263.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_070.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R022.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV19_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV11_077.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_064.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_169.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R036.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV11_063.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_070.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R022.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_277.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_064.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R036.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_121.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_149.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_257.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_T002.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R188.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R084.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_177.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R090.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_163.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_T016.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_299.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R188.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_243.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_223.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_175.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_088.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_161.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_037.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_237.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_126.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_294.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_077.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_264.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R047.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_118.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV08_128.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_206.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_063.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R053.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_270.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_212.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_001.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_132.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_280.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_118.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_T045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_266.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R163.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_113.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_130.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_272.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R177.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_188.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_258.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV15_137.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_124.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_107.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_029.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R163.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV08_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_113.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_130.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_T045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_266.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R177.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV18_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_124.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_107.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV10_072.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_272.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_091.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_227.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_098.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_T010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_029.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_003.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_210.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_T004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_272.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_017.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_204.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_266.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_T010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_178.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV03_T048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_098.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_233.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_T004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_085.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_029.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_087.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_157.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_001.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_212.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_T038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_280.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_093.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_206.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_212.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_001.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_238.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_144.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_294.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_087.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_206.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_093.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_150.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_143.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_T038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_078.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_223.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_052.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_161.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R133.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_103.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_175.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_078.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R127.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_117.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_237.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_046.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_044.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_067.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_T043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R017.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_243.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_073.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_050.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R003.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_187.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_149.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV09_267.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_257.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_299.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_044.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_067.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_T043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R017.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV05_043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV18_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_073.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_050.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_193.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R003.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_263.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_070.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_012.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_201.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_089.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_169.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R063.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_236.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_025.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV03_R149.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_121.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_T049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_293.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_135.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_287.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R077.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_222.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_031.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_T049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV02_R149.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_277.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_089.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_064.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_006.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_215.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R195.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_082.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_203.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV13_210.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R181.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_096.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_155.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK24_082.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_141.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_217.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_109.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R195.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_058.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_096.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV14_085.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_229.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R181.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_138.wav
# ...
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_096.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_285.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_033.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_242.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_162.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R152.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_298.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_176.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R146.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_019.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_027.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_256.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV13_098.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_082.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_291.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV02_T015.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_069.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_267.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_273.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R115.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_189.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_259.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R101.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_281.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R200.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_055.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_246.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R089.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_213.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_271.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_062.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R191.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R129.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_207.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R089.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_265.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_076.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R185.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_041.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_252.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV12_248.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_295.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_207.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_T024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_172.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_151.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_213.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_T030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_048.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_145.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK28_166.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_239.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_092.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_151.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_R102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_014.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_207.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_T024.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_145.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_166.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_086.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_R116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV11_200.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_213.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_T030.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK30_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_147.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_T018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_074.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_267.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_179.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_205.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R026.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_016.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_028.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_T018.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_060.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_273.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK01_R032.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_211.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_002.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK44_131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_153.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK25_179.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_242.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_042.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_114.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV17_245.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_148.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_186.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_298.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK23_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_051.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK35_192.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R061.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_100.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_109.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R075.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_045.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_184.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_236.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK33_128.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_121.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK36_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK03_R049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_174.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_102.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK42_160.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK18_135.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK02_R049.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK38_199.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_079.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK13_190.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_222.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_228.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_097.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_059.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_154.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_177.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_T017.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_011.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_202.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_290.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_163.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_083.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R189.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_T003.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R057.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_108.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R043.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK09_T017.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV10_211.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_011.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R131.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_284.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK39_177.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_097.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV07_084.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK08_T003.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R057.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_005.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK20_216.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R125.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_083.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV17_090.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_163.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_140.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_214.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_007.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_065.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_168.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV09_158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_276.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV10_239.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_134.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK31_039.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK10_R119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV19_158.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV01_R027.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK45_120.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK16_200.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK17_013.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK11_R119.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK40_071.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_262.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK21_039.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R080.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_054.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK41_289.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_197.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_159.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV12_116.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_008.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R094.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_253.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSDEV06_240.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_040.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK26_247.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_054.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_118.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_111.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK06_R080.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_040.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK34_183.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R038.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_105.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK07_R094.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK37_068.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK29_188.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_165.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_107.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R176.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_130.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK32_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_034.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK04_R010.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK46_020.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK12_R162.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK27_068.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK19_124.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK22_139.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK05_R004.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK43_171.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK14_113.wav
#   inflating: /content/ViVOS/voices/voices/VIVOSSPK15_300.wav

# %%
paths = [
    # "Common-Voice/train.json",
    # "Common-Voice/dev.json",
    # "Common-Voice/test.json",
    "ViVOS/train.json",
    "ViVOS/test.json"
]

# %%
SAMPLE_RATE = 16000
NUM_SAMPLE = 55000  # Chọn tạm để test (nên chọn lại)
TRANSFORMATION = "MFCC"
VOCAB = Vocabulary(paths)
MAX_LEN = VOCAB.max_len

# %%
# common_voice_train = CustomDataset(
#     audio_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//converted voices",
#     data_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//train.json",
#     vocab=VOCAB,
#     target_sample_rate=SAMPLE_RATE,
#     num_samples = NUM_SAMPLE,
#     transformation=TRANSFORMATION,
#     max_len=MAX_LEN
# )

# common_voice_dev = CustomDataset(
#     audio_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//converted voices",
#     data_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//dev.json",
#     vocab=VOCAB,
#     target_sample_rate=SAMPLE_RATE,
#     num_samples = NUM_SAMPLE,
#     transformation=TRANSFORMATION,
#     max_len=MAX_LEN
# )

# common_voice_test = CustomDataset(
#     audio_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//converted voices",
#     data_directory="Vietnamese-Speech-to-Text-datasets//Common-Voice//test.json",
#     vocab=VOCAB,
#     target_sample_rate=SAMPLE_RATE,
#     num_samples = NUM_SAMPLE,
#     transformation=TRANSFORMATION,
#     max_len=MAX_LEN
# )

# %%
vivos_train = CustomDataset(
    audio_directory="ViVOS/voices/voices",
    data_directory="ViVOS/train.json",
    vocab=VOCAB,
    target_sample_rate=SAMPLE_RATE,
    num_samples = NUM_SAMPLE,
    transformation=TRANSFORMATION,
    max_len=MAX_LEN
)

vivos_test = CustomDataset(
    audio_directory="ViVOS/voices/voices",
    data_directory="ViVOS/test.json",
    vocab=VOCAB,
    target_sample_rate=SAMPLE_RATE,
    num_samples = NUM_SAMPLE,
    transformation=TRANSFORMATION,
    max_len=MAX_LEN
)

# %% [markdown]
# ## Load dataloader

# %%
BATCH_SIZE = 64

# %%
# dataset = ConcatDataset([common_voice_train, common_voice_dev, common_voice_test, vivos_train, vivos_test])

# %%
# train_dataset, test_dataset = torch.utils.data.random_split(dataset, [0.8, 0.2])
# train_dataset, dev_dataset = torch.utils.data.random_split(train_dataset, [0.8, 0.2])

# %%
# train_loader = DataLoader(
#     train_dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True
# )
# dev_loader = DataLoader(
#     dev_dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True
# )
# test_loader = DataLoader(
#     test_dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True
# )

# %%
train_loader = DataLoader(
    vivos_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)
dev_loader = DataLoader(
    vivos_test,
    batch_size=BATCH_SIZE,
    shuffle=True
)

# %% [markdown]
# # Train model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from tqdm import tqdm
from speechbrain.nnet.loss.transducer_loss import TransducerLoss

# Assuming device is set up as follows:
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Acoustic model (Encoder)
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout_prob):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout_prob = dropout_prob

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=self.hidden_size,
            num_layers=self.num_layers,
            bias=True,
            batch_first=True,
            dropout=self.dropout_prob,
            bidirectional=True
        )

    def forward(self, inputs):  # inputs.size(): (batch_size, num_samples, num_mels)
        outputs, _ = self.lstm(inputs)  # outputs.size(): (batch_size, num_samples, hidden_size * 2)
        return outputs

# Language model (Decoder)
class Decoder(nn.Module):
    def __init__(self, vocab, hidden_size, num_layers, dropout_prob):
        super(Decoder, self).__init__()
        self.vocab = vocab
        self.embedding_size = len(self.vocab) - 4
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout_prob = dropout_prob
        self.start_symbol = self.vocab.bos_idx

        self.embedding = nn.Embedding(
            num_embeddings=len(self.vocab),
            embedding_dim=self.embedding_size,
            padding_idx=self.vocab.pad_idx
        )

        self.dropout = nn.Dropout(dropout_prob)

        self.lstm = nn.LSTM(
            input_size=self.embedding_size,
            hidden_size=self.hidden_size,
            num_layers=self.num_layers,
            bias=True,
            batch_first=True,
            dropout=self.dropout_prob,
            bidirectional=True
        )

    def forward(self, inputs):  # inputs.size(): (batch_size, text_len)
        batch_size = inputs.size()[0]
        text_len = inputs.size()[1]
        hidden_state = torch.zeros(self.num_layers * 2, batch_size, self.hidden_size, device=inputs.device)
        cell = torch.zeros(self.num_layers * 2, batch_size, self.hidden_size, device=inputs.device)
        outputs = []
        for i in range(text_len):
            if i == 0:
                decoder_input = (torch.tensor([self.start_symbol] * batch_size, device=inputs.device)).unsqueeze(-1)  # decoder_input.size(): (batch_size, 1)
            else:
                decoder_input = inputs[:, i].unsqueeze(-1)  # decoder_input.size(): (batch_size, 1)
            output, hidden_state, cell = self.forward_one_step(decoder_input, hidden_state, cell)
            outputs.append(output)
        outputs = torch.stack(outputs, dim=1)  # outputs.size(): (batch_size, text_len + 1, hidden_size * 2)
        outputs = outputs.squeeze(2)

        return outputs

    def forward_one_step(
            self,
            input,  # input.size(): (batch_size, 1)
            previous_hidden_state,  # hidden_state.size(): num_layers * 2, batch_size, hidden_size
            previos_cell
        ):
        embeddeding = (self.dropout(self.embedding(input)))  # embeddeding.size(): (batch_size, 1, embedding_size)
        output, (hidden_state, cell) = self.lstm(embeddeding, (previous_hidden_state, previos_cell))
        # output.size(): (batch_size, 1, 2 * hidden_size)
        # hidden_state.size(): (2 * num_layers, batch_size, hidden_size)

        return output, hidden_state, cell

# Joiner
class Joiner(nn.Module):
    MODES = {
        "multiplicative": lambda outputs_encoder, outputs_decoder: outputs_encoder * outputs_decoder,
        "additive": lambda outputs_encoder, outputs_decoder: outputs_encoder + outputs_decoder,
        # "cat": lambda outputs_encoder, outputs_decoder: torch.cat((outputs_encoder, outputs_decoder), dim=1)
    }

    def __init__(self, hidden_size, vocab, mode):
        super(Joiner, self).__init__()

        self.vocab = vocab
        self.join = self.MODES[mode]

        self.linear = nn.Linear(
            in_features=hidden_size * 2,
            out_features=len(self.vocab)
        )

    def forward(
            self,
            outputs_encoder,  # outputs_encoder.size(): (batch_size, num_samples, hidden_size * 2)
            outputs_decoder,  # outputs_decoder.size(): (batch_size, text_len + 1, hidden_size * 2)
        ):
        outputs_encoder = outputs_encoder.unsqueeze(2)  # outputs_encoder.size(): (batch_size, num_samples, 1, hidden_size * 2)
        outputs_decoder = outputs_decoder.unsqueeze(1)  # outputs_decoder.size(): (batch_size, 1, text_len + 1, hidden_size * 2)

        outputs = self.join(outputs_encoder, outputs_decoder)  # outputs.size(): (batch_size, num_samples, text_len + 1, hidden_size * 2)

        outputs = self.linear(outputs)  # outputs.size(): (batch_size, num_samples, text_len + 1, len_vocab)

        outputs = F.softmax(outputs, dim=-1)

        return outputs

# RNNT Model
class RNNT(nn.Module):
    def __init__(self, vocab, input_size, device, hidden_size = 512, num_layers_encoder = 5, num_layers_decoder = 2, dropout_prob = 0.2, mode = "additive"):
        super(RNNT, self).__init__()
        self.vocab = vocab
        self.device = device

        self.encoder = Encoder(
            input_size,
            hidden_size = hidden_size,
            num_layers = num_layers_encoder,
            dropout_prob = dropout_prob
        ).to(self.device)

        self.decoder = Decoder(
            vocab=self.vocab,
            hidden_size = hidden_size,
            num_layers = num_layers_decoder,
            dropout_prob = dropout_prob
        ).to(self.device)

        self.joiner = Joiner(
            hidden_size=hidden_size,
            vocab=self.vocab,
            mode=mode
        ).to(self.device)

    def compute_loss(self, inputs, signal_len, text_len, targets):
        outputs_encoder = self.encoder(inputs)
        outputs_decoder = self.decoder.forward(targets)
        outputs_joiner = self.joiner(outputs_encoder, outputs_decoder)

        transducer_loss = TransducerLoss(self.vocab.blank_idx)
        loss = transducer_loss(outputs_joiner, targets, signal_len, text_len)
        return loss

    def greedy_decode(self, signals, signal_lens, max_len):
        outputs_batch = []
        batch_size = signals.size()[0]
        outputs_encoder = self.encoder(signals).to(self.device)
        for b in range(batch_size):
            t = 0
            u = 0
            outputs = [self.decoder.start_symbol]
            hidden_state = self.decoder.initial_state.unsqueeze(0)
            while t < signal_lens[b] and u < max_len:
                decoder_input = torch.tensor([outputs[-1]], device=self.device)
                output, hidden_state = self.decoder.forward_one_step(decoder_input, hidden_state)
                feature_t = outputs_encoder[b, t]
                output_joiner = self.joiner.forward(feature_t, output)
                argmax = output_joiner.max(-1)[1].item()
                if argmax == self.vocab.blank_idx:
                    t += 1
                else:  # argmax == a label
                    u += 1
                    outputs.append(argmax)
            outputs_batch.append(outputs[1:-1])
        return outputs_batch

    # def forward(self, inputs, max_len): => def decode?
    #     batch_size, num_samples, num_mels = inputs.size()

    #     outputs_encoder = self.encoder(inputs)  # outputs_encoder.size(): (batch_size, num_samples, hidden_size * 2)
    #     hidden_state, cell = self.decoder.init_hidden_state(batch_size)

    #     item = self._init_sos(batch_size)  # item.size(): (batch_size, 1, 3)
    #     counter = self._init_counter(batch_size)  # counter.size(): (batch_size)

    #     counter_ceil = num_samples - 1
    #     # term_state = torch.zeros(batch_size)
    #     t = 0

    #     while True:
    #         t += 1

    #         output_encoder = (outputs_encoder[range(batch_size), counter, :]).unsqueeze(1)  # signal.size(): (batch_size, 1, hidden_size * 2)
    #         prob_consonant, prob_vowel, prob_tone, hidden_state, cell = self._predict_next(item, output_encoder, hidden_state, cell)
    #         # prob_consonant.size(): (batch_size, num_consonants)
    #         # prob_vowel.size(): (batch_size, num_vowels)
    #         # prob_tone.size(): (batch_size, num_tones)
    #         # hidden_size.size(): (num_layers * 2, batch_size, hidden_size)
    #         # cell.size(): (num_layers * 2, batch_size, hidden_size)

    #         # prob_words = torch.cat((prob_consonant, prob_vowel, prob_tone), dim=1)
    #         # prob_words = prob_words.unsqueeze(1)


    #         predicted_word = torch.cat(
    #             (
    #                 torch.argmax(prob_consonant, dim=-1).unsqueeze(-1),  # .size(): (batch_size, 1)
    #                 torch.argmax(prob_vowel, dim=-1).unsqueeze(-1),  # .size(): (batch_size, 1)
    #                 torch.argmax(prob_tone, dim=-1).unsqueeze(-1)  # .size(): (batch_size, 1)
    #             ),
    #             dim=1
    #         )  # predicted_word.size(): (batch_size, 3)
    #         predicted_word = predicted_word.unsqueeze(1) # predicted_word.size(): (batch_size, 1, 3)

    #         if t == 1:
    #             # results = prob_words
    #             predictions = predicted_word  # predictions.size(): (batch_size, 1, 3)
    #         else:
    #             # results = torch.cat([results, prob_words], dim=1)
    #             predictions = torch.cat([predictions, predicted_word], dim=1)  # predictions.size(): (batch_size, t, 3)

    #         is_blank = self._is_blank(batch_size, predicted_word)  # is_blank.size(): (batch_size, 1)
    #         item = self._update_item(is_blank, item, predicted_word)  # item.size(): (batch_size, 1, 3)

    #         counter, update_mask = self._update(is_blank, counter, counter_ceil)

    #         if (update_mask.sum().item() == batch_size) or (t == max_len):  # counter tới max của tất cả trong batch hoặc đạt max len
    #             break

    #     return predictions  # predictions.size(): (batch_size, max_len, 3)

    # def _init_sos(self, batch_size):
    #     return torch.LongTensor(np.array([self.vocab.get_index("<sos>")] * batch_size))  # (batch_size, 1, 3)

    # def _init_counter(self, batch_size):
    #     return np.zeros(batch_size, dtype=int)

    # def _predict_next(
    #         self,
    #         item,  # item.size(): (batch_size, 1, 3)
    #         output_encoder,  # output_encoder.size(): (batch_size * num_samples, hidden_size * 2)
    #         hidden_state,
    #         cell
    #     ):
    #     output, hidden_state, cell = self.decoder(item, hidden_state, cell)
    #     prob_consonant, prob_vowel, prob_tone = self.joiner(output_encoder, output)
    #     return prob_consonant, prob_vowel, prob_tone, hidden_state, cell

    # def _is_blank(self, batch_size, predicted_word):
    #     is_blank = torch.zeros((batch_size, 1), dtype=bool)
    #     for i, predicted_word in enumerate(predicted_word):
    #         is_blank[i] = torch.equal(predicted_word, torch.LongTensor(self.vocab.get_index("<blank>")))
    #     return is_blank

    # def _update_item(self, is_blank, item, predicted_word):
    #     return ((is_blank * item.squeeze()) + (~is_blank * predicted_word.squeeze())).unsqueeze(1)

    # def _update(self, is_blank, counter, counter_ceil):
    #     counter = counter + is_blank.squeeze().numpy()
    #     counter, update_mask = self._clip_counter(counter, counter_ceil)
    #     # term_state = self._update_termination_state(term_state, update_mask, t)
    #     return counter, update_mask

    # def _clip_counter(self, counter, counter_ceil):
    #     update_mask = counter >= counter_ceil  # update_mask.shape: (batch_size,) (bool)
    #     upper_bounded = update_mask * counter_ceil  # upper_bounded.shape: (batch_size,)
    #     kept_counter = (counter < counter_ceil) * counter  # kept_counter.shape: (batch_size,)
    #     return upper_bounded + kept_counter, update_mask

    # # def _update_termination_state(self, term_state, update_mask, t):
    # #     is_unended = term_state == 0
    # #     to_update = is_unended & update_mask
    # #     return term_state + to_update * t

# %%
from torch.optim import Adam
from tqdm import tqdm
import torch


class Trainer:
    def __init__(self, model, lr, vocab, device):
        self.model = model
        self.lr = lr
        self.optimizer = Adam(model.parameters(), lr=self.lr)
        self.vocab = vocab
        self.device = device

    def train(self, train_loader, max_len, print_interval=20):
        train_loss = 0
        num_samples = 0
        self.model.train()
        for index, batch in enumerate(tqdm(train_loader)):
            (signals, signal_lens), (scripts, text_lens) = batch
            signals = signals.to(self.device)
            signal_lens = signal_lens.to(self.device)
            scripts = scripts.to(self.device)
            text_lens = text_lens.to(self.device)
            batch_size = signals.size()[0]
            num_samples += batch_size
            loss = self.model.compute_loss(signals, signal_lens, text_lens, scripts)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            train_loss += loss.item() * batch_size

            if index % print_interval == 0:
                self.model.eval()
                guesses = self.model.greedy_decode(signals, signal_lens, max_len)
                print("\n")
                for b in range(2):
                    print("guess:", self.vocab.decode_script(guesses[b]))
                    print("truth:", self.vocab.decode_script(scripts[b, :text_lens[b]]))

        train_loss /= num_samples
        return train_loss

    def test(self, dev_loader, max_len, print_interval=10):
        test_loss = 0
        num_samples = 0
        self.model.eval()
        with torch.no_grad():
            for idx, batch in tqdm(dev_loader):
                (signals, signal_lens), (scripts, text_lens) = batch
                signals = signals.to(self.device)
                signal_lens = signal_lens.to(self.device)
                scripts = scripts.to(self.device)
                text_lens = text_lens.to(self.device)
                batch_size = signals.size()[0]
                num_samples += batch_size
                loss = self.model.compute_loss(signals, signal_lens, text_lens, scripts)
                test_loss += loss.item() * batch_size
                if idx % print_interval == 0:
                    print("\n")
                    print("guess:", self.vocab.decode_script(self.model.greedy_decode(signals, signal_lens, max_len)[0]))
                    print("truth:", self.vocab.decode_script(scripts[0, :text_lens[0]]))
                    print("")
        test_loss /= num_samples
        return test_loss

# %%
rnnt = RNNT(
    vocab=VOCAB,
    input_size=50,
    device=torch.device('cpu')
)

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
trainer = Trainer(model=rnnt, lr=0.0003, vocab=VOCAB, device=torch.device('cpu'))
NUM_EPOCHS = 10
train_losses = []
test_losses = []

for epoch in range(NUM_EPOCHS):
    train_loss = trainer.train(train_loader=train_loader, max_len=MAX_LEN)
    test_loss = trainer.test(dev_loader=dev_loader, max_len=MAX_LEN)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    print("Epoch %d: train loss = %f, test loss = %f" % (epoch, train_loss, test_loss))
# Out:
#   0%|          | 0/183 [01:10<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-76d1b8bea6e1> in <cell line: 7>()
#       6
#       7 for epoch in range(NUM_EPOCHS):
# ----> 8     train_loss = trainer.train(train_loader=train_loader, max_len=MAX_LEN)
#       9     test_loss = trainer.test(dev_loader=dev_loader, max_len=MAX_LEN)
#      10     train_losses.append(train_loss)
#
# <ipython-input-13-666cb98de9dd> in train(self, train_loader, max_len, print_interval)
#      24             batch_size = signals.size()[0]
#      25             num_samples += batch_size
# ---> 26             loss = self.model.compute_loss(signals, signal_lens, text_lens, scripts)
#      27             self.optimizer.zero_grad()
#      28             loss.backward()
#
# <ipython-input-12-4de215464468> in compute_loss(self, inputs, signal_len, text_len, targets)
#     159
#     160         transducer_loss = TransducerLoss(self.vocab.blank_idx)
# --> 161         loss = transducer_loss(outputs_joiner, targets, signal_len, text_len)
#     162         return loss
#     163
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/speechbrain/nnet/loss/transducer_loss.py in forward(self, logits, labels, T, U)
#     383             )
#     384         else:
# --> 385             raise ValueError(
#     386                 f"Found inputs tensors to be on {[logits.device, labels.device, T.device, U.device]} while needed to be on a 'cuda' device to use the transducer loss."
#     387             )
#
# ValueError: Found inputs tensors to be on [device(type='cpu'), device(type='cpu'), device(type='cpu'), device(type='cpu')] while needed to be on a 'cuda' device to use the transducer loss.
